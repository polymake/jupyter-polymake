# %%
@python
import ipywidgets as widgets
from IPython.display import display, clear_output

def print_cube(dim):
    kernel = get_ipython().kernel
    output=kernel._run_polymake_command( "johnson_solid(" + str(dim) +")->VISUAL" )
    stream_content = { 'wait': False }
    kernel.send_response( kernel.iopub_socket, 'clear_output', stream_content )
    stream_content = { 'data': { 'text/html': output[output.find(".@@HTML@@") + 9:-12]  } }
    kernel.send_response( kernel.iopub_socket, 'display_data', stream_content )
display(interactive(print_cube,__manual=True,dim=(1,92)))
# Out:
# <!--
# polymake for sebastian
# Sat Jan 30 17:20:04 2016
# unnamed
# -->
#
#
# <html>
# 	<head>
# 		<title>unnamed</title>
# 		<style>canvas { width: 100%; height: 100% }</style>
# 	</head>
#
# <body>
#
# <div id="model8618398617"></div>
#
# <script src="js/three.polymake.js"></script>
#
#
# <script>
# 	var container = document.getElementById( 'model8618398617' );
# 	var renderer = Detector.webgl? new THREE.WebGLRenderer({antialias: true}): new THREE.CanvasRenderer({antialias: true});
# 	var box = document.getElementsByClassName( 'input_area' )[0];
# 	var width = box.clientWidth*0.9;
# 	var height = window.innerHeight * width/(window.innerWidth);
# 	renderer.setSize(width, height);
# 	renderer.setClearColor(0xFFFFFF, 1);
#
# 	container.appendChild(renderer.domElement);
#
#
# 	var scene = new THREE.Scene();
# 	var camera = new THREE.PerspectiveCamera(75, window.innerWidth/window.innerHeight, 0.1, 1000);
#
# 	camera.position.set(0, 0, 5);
# 	camera.lookAt(0, 0, 0);
# 	camera.up.set(0, 1, 0);
#
# 	var controls = new THREE.TrackballControls(camera, container);
#
# 	var all_objects = [];
# 	var centroids = [];
# 	var obj = new THREE.Object3D();
#
# 	<!-- Vertex style -->
# 	var points_material = new THREE.MeshBasicMaterial ( {color: 0xFF0000, } );
# 	points_material.side = THREE.DoubleSide;
#
#
# 	<!-- POINTS -->
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0.5, 1.2947, -0.0374697);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-0.5, 1.2947, -0.0374697);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0.809017, 0.794705, 0.771547);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-0.809017, 0.794705, 0.771547);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0.809017, 0.794705, -0.846487);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0, 0.485688, 1.27155);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-0.809017, 0.794705, -0.846487);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0, 0.485688, -1.34649);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(1.30902, -0.0143122, 0.46253);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(1.30902, -0.0143122, -0.53747);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-1.30902, -0.0143122, 0.46253);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-1.30902, -0.0143122, -0.53747);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0, -0.514312, 1.27155);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0.809017, -0.823329, 0.771547);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0, -0.514312, -1.34649);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-0.809017, -0.823329, 0.771547);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0.809017, -0.823329, -0.846487);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-0.809017, -0.823329, -0.846487);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0.5, -1.32333, -0.0374697);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-0.5, -1.32333, -0.0374697);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(1.39443, 0.847491, -0.0374697);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(0, -1.40874, 0.824334);
# 	obj.add(sphere);
# 	var sphere = new THREE.Mesh(new THREE.SphereGeometry(0.02), points_material);
# 	sphere.position.set(-1.39443, 0.847491, -0.0374697);
# 	obj.add(sphere);
# 	makelabel("0", 0.5, 1.2947, -0.0374697);
# 	makelabel("1", -0.5, 1.2947, -0.0374697);
# 	makelabel("2", 0.809017, 0.794705, 0.771547);
# 	makelabel("3", -0.809017, 0.794705, 0.771547);
# 	makelabel("4", 0.809017, 0.794705, -0.846487);
# 	makelabel("5", 0, 0.485688, 1.27155);
# 	makelabel("6", -0.809017, 0.794705, -0.846487);
# 	makelabel("7", 0, 0.485688, -1.34649);
# 	makelabel("8", 1.30902, -0.0143122, 0.46253);
# 	makelabel("9", 1.30902, -0.0143122, -0.53747);
# 	makelabel("10", -1.30902, -0.0143122, 0.46253);
# 	makelabel("11", -1.30902, -0.0143122, -0.53747);
# 	makelabel("12", 0, -0.514312, 1.27155);
# 	makelabel("13", 0.809017, -0.823329, 0.771547);
# 	makelabel("14", 0, -0.514312, -1.34649);
# 	makelabel("15", -0.809017, -0.823329, 0.771547);
# 	makelabel("16", 0.809017, -0.823329, -0.846487);
# 	makelabel("17", -0.809017, -0.823329, -0.846487);
# 	makelabel("18", 0.5, -1.32333, -0.0374697);
# 	makelabel("19", -0.5, -1.32333, -0.0374697);
# 	makelabel("20", 1.39443, 0.847491, -0.0374697);
# 	makelabel("21", 0, -1.40874, 0.824334);
# 	makelabel("22", -1.39443, 0.847491, -0.0374697);
#
# 	var faces = new THREE.Geometry();
#
#    <!-- VERTICES -->
# 	faces.vertices.push(new THREE.Vector3(0.5, 1.2947, -0.0374697));
# 	faces.vertices.push(new THREE.Vector3(-0.5, 1.2947, -0.0374697));
# 	faces.vertices.push(new THREE.Vector3(0.809017, 0.794705, 0.771547));
# 	faces.vertices.push(new THREE.Vector3(-0.809017, 0.794705, 0.771547));
# 	faces.vertices.push(new THREE.Vector3(0.809017, 0.794705, -0.846487));
# 	faces.vertices.push(new THREE.Vector3(0, 0.485688, 1.27155));
# 	faces.vertices.push(new THREE.Vector3(-0.809017, 0.794705, -0.846487));
# 	faces.vertices.push(new THREE.Vector3(0, 0.485688, -1.34649));
# 	faces.vertices.push(new THREE.Vector3(1.30902, -0.0143122, 0.46253));
# 	faces.vertices.push(new THREE.Vector3(1.30902, -0.0143122, -0.53747));
# 	faces.vertices.push(new THREE.Vector3(-1.30902, -0.0143122, 0.46253));
# 	faces.vertices.push(new THREE.Vector3(-1.30902, -0.0143122, -0.53747));
# 	faces.vertices.push(new THREE.Vector3(0, -0.514312, 1.27155));
# 	faces.vertices.push(new THREE.Vector3(0.809017, -0.823329, 0.771547));
# 	faces.vertices.push(new THREE.Vector3(0, -0.514312, -1.34649));
# 	faces.vertices.push(new THREE.Vector3(-0.809017, -0.823329, 0.771547));
# 	faces.vertices.push(new THREE.Vector3(0.809017, -0.823329, -0.846487));
# 	faces.vertices.push(new THREE.Vector3(-0.809017, -0.823329, -0.846487));
# 	faces.vertices.push(new THREE.Vector3(0.5, -1.32333, -0.0374697));
# 	faces.vertices.push(new THREE.Vector3(-0.5, -1.32333, -0.0374697));
# 	faces.vertices.push(new THREE.Vector3(1.39443, 0.847491, -0.0374697));
# 	faces.vertices.push(new THREE.Vector3(0, -1.40874, 0.824334));
# 	faces.vertices.push(new THREE.Vector3(-1.39443, 0.847491, -0.0374697));
#
# 	centroids.push(computeCentroid(faces));
#
# 	<!-- Facet style -->
# 	var faces_material = new THREE.MeshBasicMaterial ( {color: 0x77EC9E, } );
# 	faces_material.side = THREE.DoubleSide;
#
#
#    <!-- FACETS -->
# 	faces.faces.push(new THREE.Face3(8, 13, 18, undefined, undefined, 0));
# 	faces.faces.push(new THREE.Face3(8, 18, 16, undefined, undefined, 0));
# 	faces.faces.push(new THREE.Face3(8, 16, 9, undefined, undefined, 0));
#
# 	faces.faces.push(new THREE.Face3(12, 13, 8, undefined, undefined, 0));
# 	faces.faces.push(new THREE.Face3(12, 8, 2, undefined, undefined, 0));
# 	faces.faces.push(new THREE.Face3(12, 2, 5, undefined, undef
